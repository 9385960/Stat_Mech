# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as ipw

# %% [markdown]
# # Energy of a Classical Ideal Gas
#
# Assuming that the particles are non interacting and moving and speeds much slower than the speed of light, then classically, these particles will each cary some kinetic energy. The total kinetic energy will be given by:
#
# $ E = \frac{1}{2} m v^2$
